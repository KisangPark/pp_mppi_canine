# %% [markdown]
# # Make Canine Scene

# %%
import mujoco as mj 
import mujoco_viewer

# %%
""" LOAD MJCF & CREATE ENVIRONMENT """
model = mj.MjModel.from_xml_path('./asset/scene.xml')
data = mj.MjData(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 """ LOAD MJCF & CREATE ENVIRONMENT """
# ----> 2 model = mj.MjModel.from_xml_path('./asset/scene.xml')
#       3 data = mj.MjData(model)
#
# ValueError: Error: size 0 must be positive in geom
# Element name '', id 7, line 0

# %%
""" CREATE VIEWER & RENDER """

viewer = mujoco_viewer.MujocoViewer(model, data)
mj.mj_resetData(model, data)

while True:
    if viewer.is_alive:
        mj.mj_step(model, data)
        viewer.render()
    else:
        break

# close
viewer.close()
# Out:
# WARNING: Nan, Inf or huge value in QACC at DOF 11. The simulation is unstable. Time = 0.0380.
#
# Pressed ESC
# Quitting.
