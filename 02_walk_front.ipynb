# %% [markdown]
# # Front Walking with MPPI Control

# %%
import mujoco as mj 
import mujoco_viewer

# %%
""" LOAD MJCF & CREATE ENVIRONMENT """
model = mj.MjModel.from_xml_path('./asset/scene.xml')
data = mj.MjData(model)

# %%
""" CREATE VIEWER & RENDER """

viewer = mujoco_viewer.MujocoViewer(model, data)
mj.mj_resetData(model, data)

while True:
    if viewer.is_alive:
        mj.mj_step(model, data)
        viewer.render()
    else:
        break

# close
viewer.close()
# Out:
# 2026-02-11 00:57:15.033 python[8074:29642619] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Pressed ESC
# Quitting.
