# %% [markdown]
# # 1. MPPI - Standing
# - Because control frequency should exceed at least 100Hz, real time control using mujoco python is impossible
# - The control values are saved with npy array and then replayed for real time control

# %% [markdown]
# #### 0. Load scene

# %%
import os
import sys
import numpy as np
import time
import mujoco

sys.path.append(os.path.abspath('../'))
from package.pp_base_mujoco.VIEWER import *
from package.pp_base_mujoco.KINEMATICS import *
from package.pp_base_mujoco.UTILS import *

# %%
xml_path = './asset/canine_scene.xml'
xml_abs_path = os.path.abspath(xml_path)

model = mujoco.MjModel.from_xml_path(xml_abs_path)
data = mujoco.MjData(model)
model.opt.timestep = 0.01 # 1000Hz control

joint_names = [
    'FL_HIP_JOINT', 'FL_THIGH_JOINT', 'FL_KNEE_JOINT',
    'FR_HIP_JOINT', 'FR_THIGH_JOINT', 'FR_KNEE_JOINT',
    'HL_HIP_JOINT', 'HL_THIGH_JOINT', 'HL_KNEE_JOINT',
    'HR_HIP_JOINT', 'HR_THIGH_JOINT', 'HR_KNEE_JOINT']
q_init = np.array([0, 2.3, -2.6,0, 2.3, -2.6,0, 2.3, -2.6,0, 2.3, -2.6])
apply_qpos_names(model, data, joint_names, q_init)
apply_qpos_freejoint(model, data, p=[0, 0, 0.095], rpy=[0, 0, 0])
mujoco.mj_forward(model, data)

# %% [markdown]
# #### 1. Declare MPPI Controller

# %%
""" COST FUNCTION MPPI """
target_p = np.array([0, 0, 0.3]) # target body position
target_R = np.eye(3) # target body rotation
def cost_function_standing(model, data):
    # 1. calculate cost according to target body xpos
    body_p = data.xpos[mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_BODY, "base_link")]
    cost_position = np.linalg.norm(body_p - target_p)
    # 2. calculate cost according to body rotation
    body_R = data.xmat[mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_BODY, "base_link")].reshape(3, 3)
    cost_rotation = np.linalg.norm(body_R - target_R)
    # 3. penalize high joint velocities 
    joint_velocities = data.qvel
    cost_velocity = np.linalg.norm(joint_velocities)
    # 4. normalize costs    cost_position /= 0.3 # max expected position error
    cost_rotation /= np.linalg.norm(np.eye(3)) # max expected rotation error
    cost_velocity /= 10.0 # max expected velocity
    # 4. sum
    return cost_position + cost_rotation + cost_velocity

# %%
# """ MOVING AVERAGE FILTER FOR SMOOTH FILTER """
# def moving_average_filter(ctrl, window_size=10):
#     filtered_sequence = np.zeros_like(ctrl)
#     for t in range(len(ctrl)):
#         start_idx = max(0, t - window_size + 1)
#         filtered_sequence[t] = np.mean(ctrl[start_idx:t+1], axis=0)
#     return filtered_sequence

# %%
""" MPPI CONTROLLER CLASS """

class MPPICONTROLLER:
    def __init__(
            self,
            model,
            data,
            cost_function,
            n_sample            = 100,
            horizon             = 100, # mujoco steps
            execution_step      = 1, # seconds
            ctrl_scale          = 1000.0,
            lambda_             = 1.0,
            alpha               = 0.5,
            sigma               = 0.5,
            exploration_rate    = 0.1
        ):
        self.model              = model
        self.data               = data
        self.cost_function      = cost_function
        self.n_sample           = n_sample
        self.horizon            = horizon
        self.ctrl_scale          = ctrl_scale

        self.sigma              = sigma
        self.lambda_            = lambda_
        self.alpha              = alpha
        self.gamma              = lambda_ * (1.0 - alpha)
        self.exploration_rate   = exploration_rate

        self.n_ctrl             = model.nu
        self.ctrl               = np.zeros((horizon, self.n_ctrl)) # initial control sequence
        self.epsilon           = np.zeros((n_sample, horizon, self.n_ctrl)) # noise for control sequence

    def sample_epsilon(self, uniform=False, beta=0.8):
        """
        SAMPLE RANDOM NOISE OF DIMENSION (n_sample, horizon, n_ctrl)
        use:
            - n_sample, horizon, n_ctrl For dimension
            - sigma for noise scale
        return:
            - epsilon: (n_sample, horizon, n_ctrl) random noise for control sequence
        """
        if uniform:
            raw_noise = np.random.uniform(
                low     = -self.sigma,
                high    = self.sigma,
                size    = (self.n_sample, self.horizon, self.n_ctrl)
            )
        else:
            raw_noise = np.random.normal(
                loc     = 0.0,
                scale   = self.sigma,
                size    = (self.n_sample, self.horizon, self.n_ctrl)
            )
        raw_noise = raw_noise * self.ctrl_scale
        self.epsilon = np.zeros_like(raw_noise)
        self.epsilon[:, 0, :] = raw_noise[:, 0, :]
        for t in range(1, self.horizon):
            self.epsilon[:, t, :] = beta * self.epsilon[:, t-1, :] + (1.0 - beta) * raw_noise[:, t, :]
            
        return self.epsilon
    
    def get_ctrl_input(self, uniform=False):  
        """ 
        CALCULATE CONTROL INPUT
        """
        self.ctrl_exploit = np.repeat(self.ctrl[np.newaxis, :, :], self.n_sample, axis=0) # (n_sample, horizon, n_ctrl)

        # if np.random.rand() > self.exploration_rate: # exploitation
        #     self.ctrl_sampled = self.ctrl_exploit + self.epsilon
        # else:
        #     self.ctrl_sampled = self.epsilon 

        # self.ctrl_sampled = self.ctrl_exploit + self.epsilon
        # print("control exploit shape:", self.ctrl_exploit.shape)
        # print("epsilon shape:", self.epsilon.shape)
        self.ctrl_sampled = self.ctrl_exploit + self.epsilon
        return self.ctrl_sampled
    
    def calc_simulated_cost (self): 
        """
        GENERATE CONTROL SIGNAL & SIMULATE COST
        """
        # save data for reset 
        qpos_bu, qvel_bu = self.data.qpos.copy(), self.data.qvel.copy()
        # initialize costs 
        costs = np.zeros(self.n_sample)
        # simulate each control inputs
        for k in range(self.n_sample):
            self.data.qpos[:] = qpos_bu
            self.data.qvel[:] = qvel_bu
            mujoco.mj_forward(self.model, self.data)
            cost_single_traj = 0.0
            for t in range(self.horizon):
                # simulator step
                self.data.ctrl[:] = self.ctrl_sampled[k, t, :]
                mujoco.mj_step(self.model, self.data)
                # calculate cost
                cost_single_step = self.cost_function(model,data)
                cost_single_traj += cost_single_step
            costs[k] = cost_single_traj 
            u = self.ctrl
            v = self.ctrl_sampled[k]
            # calculate stage cost
            costs[k] += (self.gamma * u * (1.0/self.sigma) * v).sum()
            # add terminal cost here
            # shape of costs: (n_sample,)
        self.data.qpos[:] = qpos_bu
        self.data.qvel[:] = qvel_bu
        mujoco.mj_forward(self.model, self.data)
        self.costs = costs
        return costs
    
    def compute_weights(self):
        """ COMPUTE WEIGHTS FROM COSTS """
        rho = self.costs.min()
        # calculate etas
        etas = np.exp( (-1.0/self.lambda_) * (self.costs-rho))
        self.weights = etas / etas.sum()
        return self.weights

    def return_action(self):
        """ WEIGHTED AVERAGE & RETURN FIRST ACTION """
        # weights_averaged = moving_average_filter(self.weights, window_size=10)
        weighted_epsilon = (self.weights[:, np.newaxis, np.newaxis] * self.epsilon).sum(axis=0)
        self.ctrl = self.ctrl + weighted_epsilon

        action = self.ctrl[0] 

        # receding horizon shift
        self.ctrl[:-1] = self.ctrl[1:]
        self.ctrl[-1] = self.ctrl[-2] # or 0
        
        return action

# %% [markdown]
# #### 2. Main loop

# %%
full_joint_names = get_joint_names(model,data)
print("full joint names:", full_joint_names)
print("joint types:", model.jnt_type)

joint_names = [
    'FL_HIP_JOINT', 'FL_THIGH_JOINT', 'FL_KNEE_JOINT',
    'FR_HIP_JOINT', 'FR_THIGH_JOINT', 'FR_KNEE_JOINT',
    'HL_HIP_JOINT', 'HL_THIGH_JOINT', 'HL_KNEE_JOINT',
    'HR_HIP_JOINT', 'HR_THIGH_JOINT', 'HR_KNEE_JOINT']
q_init = np.array([0, 2.3, -2.6,0, 2.3, -2.6,0, 2.3, -2.6,0, 2.3, -2.6])
apply_qpos_names(model, data, joint_names, q_init)
apply_qpos_freejoint(model, data, p=[0, 0, 0.095], rpy=[0, 0, 0])
mujoco.mj_forward(model, data)
# Out:
# full joint names: [None, 'FL_HIP_JOINT', 'FL_THIGH_JOINT', 'FL_KNEE_JOINT', 'FR_HIP_JOINT', 'FR_THIGH_JOINT', 'FR_KNEE_JOINT', 'HL_HIP_JOINT', 'HL_THIGH_JOINT', 'HL_KNEE_JOINT', 'HR_HIP_JOINT', 'HR_THIGH_JOINT', 'HR_KNEE_JOINT']
# joint types: [0 3 3 3 3 3 3 3 3 3 3 3 3]

# %%
""" MAIN LOOP - CALCULATION """
mppi_controller = MPPICONTROLLER(
    model=model,
    data=data,
    cost_function=cost_function_standing,
    n_sample=101,
    horizon=100,
    lambda_=1.0,
    alpha=0.5,
    sigma=0.5,
    exploration_rate=0.1,
    ctrl_scale=10.0
)

total_steps = 500
ctrl_list = []

for step in range(total_steps):
    start_time = time.time()
    epsilon = mppi_controller.sample_epsilon()
    ctrl_sampled = mppi_controller.get_ctrl_input()
    costs = mppi_controller.calc_simulated_cost()
    weights = mppi_controller.compute_weights()
    action = mppi_controller.return_action()
    # apply action to simulator
    data.ctrl[:] = action
    mujoco.mj_step(model, data)
    ctrl_list.append(action)
    duration = time.time() - start_time
    print(f"\r Step: {step}, Cost: {costs.min():.4f}, Duration: {duration:.4f} seconds", end="")
# Out:
#  Step: 2, Cost: 6012.5515, Duration: 0.3774 secondsWARNING: Nan, Inf or huge value in QACC at DOF 16. The simulation is unstable. Time = 359.5000.
#
#  Step: 499, Cost: 58802.1712, Duration: 0.4253 seconds

# %%
# save ctrl_list to npy file
ctrl_array = np.array(ctrl_list)
np.save("data/ctrl_list_3.npy", ctrl_array)

# %%
full_joint_names = get_joint_names(model,data)
print("full joint names:", full_joint_names)
print("joint types:", model.jnt_type)

joint_names = [
    'FL_HIP_JOINT', 'FL_THIGH_JOINT', 'FL_KNEE_JOINT',
    'FR_HIP_JOINT', 'FR_THIGH_JOINT', 'FR_KNEE_JOINT',
    'HL_HIP_JOINT', 'HL_THIGH_JOINT', 'HL_KNEE_JOINT',
    'HR_HIP_JOINT', 'HR_THIGH_JOINT', 'HR_KNEE_JOINT']
q_init = np.array([0, 2.3, -2.6,0, 2.3, -2.6,0, 2.3, -2.6,0, 2.3, -2.6])
apply_qpos_names(model, data, joint_names, q_init)
apply_qpos_freejoint(model, data, p=[0, 0, 0.095], rpy=[0, 0, 0])
mujoco.mj_forward(model, data)
# Out:
# full joint names: [None, 'FL_HIP_JOINT', 'FL_THIGH_JOINT', 'FL_KNEE_JOINT', 'FR_HIP_JOINT', 'FR_THIGH_JOINT', 'FR_KNEE_JOINT', 'HL_HIP_JOINT', 'HL_THIGH_JOINT', 'HL_KNEE_JOINT', 'HR_HIP_JOINT', 'HR_THIGH_JOINT', 'HR_KNEE_JOINT']
# joint types: [0 3 3 3 3 3 3 3 3 3 3 3 3]

# %%
""" MAIN LOOP - CALCULATION """

viewer = MUJOCOGLVIEWER(model, data, window_size=(800, 600))
viewer.view_geom(group=0, show=True)
viewer.view_contact_forces(show=True)

idx = 0

while viewer.is_alive():
    data.ctrl[:] = ctrl_list[idx]
    print(f"\r Step: {idx}, Ctrl: {ctrl_list[idx]}", end="")
    if idx >= len(ctrl_list)-1:
        pass
    else:
        idx += 1
    mujoco.mj_step(model, data)
    viewer.render()
    time.sleep(0.01) # 100Hz rendering

# close
viewer.close()
del(viewer)
# Out:
#  Step: 0, Ctrl: [-5.43097354 -4.38130179 -2.59956807  7.97986384  2.4173874  -2.05481396
#  Step: 1, Ctrl: [ -4.64544785 -11.00151346   2.04880936   3.42150113  -6.33989035
#    2.17601805   0.60249141   0.50120593   1.3047946    0.4297564
#  Step: 2, Ctrl: [-5.12934136 -9.54199301 10.22045587  3.40274861 -3.87406554  0.34021123
#  Step: 3, Ctrl: [-4.65545819 -9.15085545 -5.74535475  3.02638784 -2.61509006 -6.38911869
#  Step: 4, Ctrl: [ -1.52375948 -10.5324534   -1.40564612   3.11820168  -6.19113186
#   -3.60801726  -5.34271541   7.69906517  -1.80307542   2.49965496
#  Step: 5, Ctrl: [  3.31976795 -11.4159793   -2.84634556  -0.66321491  -2.13995395
#   -2.49121089  -4.8753612   -3.06839802  -7.05996716   5.16388011
#  Step: 6, Ctrl: [ 2.75564578 -4.44359244  1.54668714  6.37702508 -3.11310818 -2.66874676
#  Step: 7, Ctrl: [ 2.71069111 -9.35526214 10.48480676  4.38461682  1.6466068  -4.51875262
#  Step: 8, Ctrl: [ 3.36621046 -2.1288601   1.42006203  1.62610608  0.10476185 -4.66877633
#  Step: 9, Ctrl: [-3.4147785  -3.17618457  7.79255713 -7.32263688 -2.60693948  0.90684756
#  Step: 10, Ctrl: [-2.40231784e+00  3.06466450e-01 -4.65109142e+00 -6.40465714e+00
#  -5.11329044e-03  8.23761474e+00  4.29430163e+00  1.18282505e+00
#  Step: 11, Ctrl: [10.17585289  2.84192443 -0.59735306 -8.85792476  1.06645449  8.81714928
#  Step: 12, Ctrl: [  8.41512909  -2.67939764  -5.35390857 -12.19964898   5.50289466
#    7.83140732   4.91830789  -1.61279875   3.72468167  10.3385861
#  Step: 13, Ctrl: [ 7.79067811  3.46892602  1.84214127 -1.28429671  1.83487201  7.39770493
#  Step: 14, Ctrl: [  9.935573    -3.04038508  -6.59354273   9.67947598 -13.47090584
